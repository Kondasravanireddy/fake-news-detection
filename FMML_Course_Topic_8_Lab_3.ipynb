# %% [markdown]
# <a href="https://colab.research.google.com/github/Kondasravanireddy/fake-news-detection/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 14:43:22--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   206MB/s    in 0.3s
#
# 2024-03-26 14:43:22 (206 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9302    1111.5312v1  Temporal networks are ubiquitous and evolve ov...    cs
# 5230    1203.3496v1  We present a Dirichlet process mixture model o...    cs
# 954    1502.02072v1  Massively multitask neural architectures provi...  stat
# 6992   1708.07644v1  This paper is concerned with structured machin...  stat
# 21107  1707.09704v1  I propose the purpose our concept of actual ca...    cs
# ...             ...                                                ...   ...
# 24306   1307.5748v1  In video-surveillance, person re-identificatio...    cs
# 1433   1711.01243v2  Recent efforts on training light-weight binary...    cs
# 26275  1609.06371v3  The robust estimator presented in this paper p...    cs
# 32239   1305.6663v4  Recent work has shown how denoising and contra...    cs
# 11882  1703.03862v1  Feature extraction and dimension reduction for...  stat
#
#                                                    title  year  \
# 9302   Representations and Ensemble Methods for Dynam...  2011
# 5230   Dirichlet Process Mixtures of Generalized Mall...  2012
# 954      Massively Multitask Networks for Drug Discovery  2015
# 6992   Joint Structured Learning and Predictions unde...  2017
# 21107                          Cost and Actual Causation  2017
# ...                                                  ...   ...
# 24306  Appearance Descriptors for Person Re-identific...  2013
# 1433           ResBinNet: Residual Binary Neural Network  2017
# 26275    Robust Estimation of Multiple Inlier Structures  2016
# 32239  Generalized Denoising Auto-Encoders as Generat...  2013
# 11882                          Joint Embedding of Graphs  2017
#
#                                                 keywords
# 9302   [ubiquitous, attributes, relational, informati...
# 5230   [dirichlet, incomplete, inference, techniques,...
# 954    [massively, multitask, architectures, framewor...
# 6992   [concerned, structured, supervised, discusses,...
# 21107  [causation, minimizing, intervention, causatio...
# ...                                                  ...
# 24306  [surveillance, identification, recognising, in...
# 1433   [promising, executionmemory, efficiency, intro...
# 26275  [estimator, presented, processes, structure, i...
# 32239  [denoising, contractive, autoencoders, implici...
# 11882  [extraction, dimension, reduction, efficiently...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9302     [ubiquitous, attributes, relational, informati...
# 5230     [dirichlet, incomplete, inference, techniques,...
# 954      [massively, multitask, architectures, framewor...
# 6992     [concerned, structured, supervised, discusses,...
# 21107    [causation, minimizing, intervention, causatio...
#                                ...
# 12981    [estimating, dimensional, regression, regulari...
# 22213    [regression, predictive, efficiently, particul...
# 13143    [revolutionised, mathematical, computation, st...
# 14577    [independent, recognition, background, informa...
# 28171    [detection, effective, limitation, information...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8822 words.
# Out of those 4577 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5620d0f1-713f-4c58-9c5c-37d7e8a1b345" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5620d0f1-713f-4c58-9c5c-37d7e8a1b345")) {                    Plotly.newPlot(                        "5620d0f1-713f-4c58-9c5c-37d7e8a1b345",                        [{"x":["framework","relational","ubiquitous","components","demonstrate","techniques","component","necessity","statistical","evaluated","predicting","classifiers","selecting","representations","classifier","outperform","competing","discovering","representation","algorithms","attributes","ensembles","granularity","sophisticated","information","influence","capability","snapshots","additionally","classification","traditional","dimension","clusterings","approximation","incomplete","parameters","convergence","subcomponent","alternative","realworld","generalized","exploring","posterior","conditional","approximations","clustering","advantage","applicability","dirichlet","posteriors","estimating","effectiveness","improving","marginalizes","inference","empirically","transferability","discovery","empirical","architectures","innovation","interesting","contribute","accuracies","massively","biological","multitask","accelerate","investigate","algorithmic","performing","underscore","significantly","improvement","synthesizes","predictive","additional","measurements","structured","predictions","discusses","understanding","supervised","contributed","interdependent","concerned","different","performance","extension","implementation","available","constraints","causation","continuity","sufficiency","literature","exploratory","correspond","incorporating","abnormality","modelling","minimizing","definitions","intuition","intervention","application","minimization","definition","incorporates","experimental","congested","attention","variation","locations","challenging","reliability","adaptively","conditions","separately","inevitable","overestimate","detection","appropriate","densities","accurately","exclusively","generating","sufficient","applications","estimation","regression","estimations","underlying","experiments","harmonization","argumentative","brazilian","languages","treebanks","competitive","including","knowledge","annotated","documents","portuguese","linguistic","discourse","structure","evaluating","attracted","processes","euclidean","reproducing","suggested","superiority","confirmed","functions","characterizes","previously","independent","regressions","approximates","respective","fundamental","characterizations","classifications","construction","probability","explicitly","characterization","criterion","distribution","probabilistic","dependency","bidirectional","architecture","propagation","character","introduce","combination","efficiently","automatically","projective","directional","exploiting","marginals","partition","procedure","convolutional","categories","microsoft","optimizing","qualitative","quantitatively","effectively","extensive","instances","embedding","connections","development"],"y":[553,46,10,106,559,388,122,15,166,137,92,136,56,246,159,104,20,30,393,595,75,11,12,32,689,43,56,1,63,540,189,71,5,115,29,285,100,2,96,3,72,30,39,93,34,141,91,31,20,4,57,203,127,1,212,83,2,64,141,118,4,66,25,29,5,47,6,21,121,39,91,2,256,145,1,55,117,50,99,81,11,166,206,7,1,15,749,917,78,116,289,153,4,5,2,143,11,35,60,6,52,52,17,18,21,205,62,46,29,369,2,183,55,43,265,28,24,135,30,4,4,373,82,6,57,5,103,65,433,209,102,11,126,610,2,2,2,100,3,118,231,325,64,70,2,64,18,326,57,24,98,41,6,27,34,9,233,10,91,131,1,10,21,76,5,9,80,157,49,20,57,204,167,40,22,222,72,55,355,172,144,178,3,13,80,6,29,106,380,83,8,40,53,23,100,165,107,104,53,127],"type":"bar"},{"x":["framework","relational","ubiquitous","components","dem ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4577,), (4577, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Basic</span> <span style=''>Formal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Properties</span> <span style=''>of</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.4153846153846153);'>Relational</span> <span style=''>Model</span> <span style=''>of</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mathematical</span> <span style=''>Theory</span> <span style=''>of</span> <span style=''>Evidence</span> <br/><br/><span style=''>The</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>view</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Dempster</span> <span style=''>Shafer</span> <span style=''>belief</span> <span style=''>function</span> <span style=''>as</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.45238095238095233);'>diversity</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4153846153846153);'>relational</span> <span style=''>data</span> <span style=''>bases</span> <span style=''>It</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>that</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>The</span> <span style=''>Dempster</span> <span style=''>rule</span> <span style=''>of</span> <span style=''>evidence</span> <span style='background-color:rgba(0, 255, 0, 0.4333333333333333);'>combination</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>the</span> <span style=''>join</span> <span style=''>operator</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4153846153846153);'>relational</span> <span style=''>database</span> <span style=''>theory</span> <span style=''>This</span> <span style=''>rough</span> <span style=''>set</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.5588235294117646);'>qualitative</span> <span style=''>in</span> <span style=''>nature</span> <span style=''>and</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.32121212121212117);'>represent</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>belief</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.408450704225352);'>operators</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>has</span> <span style=''>the</span> <span style=''>property</span> <span style=''>that</span> <span style=''>Given</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>definition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>belief</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>domain</span> <span style=''>we</span> <span style=''>can</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.4565217391304348);'>operations</span> <span style=''>in</span> <span style=''>this</span> <span style=''>domain</span> <span style=''>and</span> <span style=''>the</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>object</span> <span style=''>is</span> <span style=''>derivable</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Feedback</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>for</span> <span style=''>Live</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictors</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>that</span> <span style=''>is</span> <span style=''>deployed</span> <span style=''>in</span> <span style=''>a</span> <span style=''>live</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>production</span> <span style=''>system</span> <span style=''>may</span> <span style=''>perturb</span> <span style=''>the</span> <span style=''>features</span> <span style=''>it</span> <span style=''>uses</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>Such</span> <span style=''>a</span> <span style=''>feedback</span> <span style=''>loop</span> <span style=''>can</span> <span style=''>occur</span> <span style=''>for</span> <span style=''>example</span> <span style=''>when</span> <span style=''>a</span> <span style=''>model</span> <span style=''>that</span> <span style=''>predicts</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>type</span> <span style=''>of</span> <span style=''>behavior</span> <span style=''>ends</span> <span style=''>up</span> <span style=''>causing</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>it</span> <span style=''>predicts</span> <span style=''>thus</span> <span style=''>creating</span> <span style=''>a</span> <span style=''>self</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fulfilling</span> <span style=''>prophecy</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>analyze</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>feedback</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>as</span> <span style=''>a</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>problem</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomization</span> <span style=''>scheme</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>feedback</span> <span style=''>in</span> <span style=''>real</span> <span style=''>world</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>conduct</span> <span style=''>a</span> <span style=''>pilot</span> <span style=''>study</span> <span style=''>for</span> <span style=''>our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>currently</span> <span style=''>deployed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>part</span> <span style=''>of</span> <span style=''>a</span> <span style=''>search</span> <span style=''>engine</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.35265700483091794);'>Regularization</span> <span style=''>of</span> <span style=''>Some</span> <span style=''>Inverse</span> <span style=''>Problems</span> <span style=''>in</span> <span style=''>Image</span> <span style=''>Analysis</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.35265700483091794);'>regularization</span> <span style=''>scheme</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>composite</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>functionals</span> <span style=''>arising</span> <span style=''>in</span> <span style=''>image</span> <span style=''>analysis</span> <span style=''>problems</span> <span style=''>The</span> <span style=''>scheme</span> <span style='background-color:rgba(0, 255, 0, 0.3433962264150943);'>automatically</span> <span style=''>trades</span> <span style=''>off</span> <span style=''>data</span> <span style=''>fidelity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.35265700483091794);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>the</span> <span style=''>current</span> <span style=''>data</span> <span style=''>fit</span> <span style=''>during</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>so</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.35265700483091794);'>regularization</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strongest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initially</span> <span style=''>and</span> <span style=''>wanes</span> <span style=''>as</span> <span style=''>data</span> <span style=''>fidelity</span> <span style=''>improves</span> <span style=''>with</span> <span style=''>the</span> <span style=''>weight</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>being</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimized</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.37304075235109724);'>convergence</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Huber</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>in</span> <span style=''>both</span> <span style=''>data</span> <span style=''>fidelity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.35265700483091794);'>regularization</span> <span style=''>terms</span> <span style=''>and</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3150684931506849);'>alternating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.36);'>multipliers</span> <span style=''>(ADMM)</span> <span style=''>using</span> <span style=''>the</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sharing</span> <span style=''>Hash</span> <span style=''>Codes</span> <span style=''>for</span> <span style=''>Multiple</span> <span style=''>Purposes</span> <br/><br/><span style=''>Locality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>hashing</span> <span style=''>(LSH)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinear</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>search</span> <span style=''>and</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>hashing</span> <span style=''>schemes</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>measures</span> <span style=''>However</span> <span style=''>hash</span> <span style=''>codes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prohibits</span> <span style=''>users</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adjusting</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>at</span> <span style=''>query</span> <span style=''>time</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>multiple</span> <span style=''>purpose</span> <span style=''>LSH</span> <span style=''>(mp</span> <span style=''>LSH)</span> <span style=''>which</span> <span style=''>shares</span> <span style=''>the</span> <span style=''>hash</span> <span style=''>codes</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarities</span> <span style=''>mp</span> <span style=''>LSH</span> <span style=''>supports</span> <span style=''>L2</span> <span style=''>cosine</span> <span style=''>and</span> <span style=''>inner</span> <span style=''>product</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarities</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>weighted</span> <span style=''>sums</span> <span style=''>where</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>can</span> <span style=''>be</span> <span style=''>adjusted</span> <span style=''>at</span> <span style=''>query</span> <span style=''>time</span> <span style=''>It</span> <span style=''>also</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>modify</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>pre</span> <span style=''>defined</span> <span style=''>groups</span> <span style=''>of</span> <span style=''>features</span> <span style=''>Thus</span> <span style=''>mp</span> <span style=''>LSH</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>for</span> <span style=''>example</span> <span style=''>to</span> <span style=''>retrieve</span> <span style=''>similar</span> <span style=''>items</span> <span style=''>to</span> <span style=''>a</span> <span style ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13268608414239483)
# 	architecture (0.07982740021574973)
# 	processing (0.10355987055016182)
# 	information (0.24775260697590795)
# 	representation (0.1413160733549083)
# 	segmentation (0.07407407407407407)
# 	detection (0.13412441567781375)
# 	different (0.26932758000719165)
# 	recognition (0.13556274721323264)
# 	convolutional (0.13664149586479685)
#
# Some Statistics words are:
# 	theoretical (0.1426448736998514)
# 	statistical (0.1515601783060921)
# 	variables (0.13967310549777118)
# 	stochastic (0.13719663199603765)
# 	estimation (0.1723625557206538)
# 	algorithm (0.3937592867756315)
# 	dimensional (0.18375433382862805)
# 	distribution (0.19415552253590887)
# 	inference (0.20356612184249628)
# 	regression (0.17830609212481427)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2774cc3b-de61-4fcb-88aa-d52137894504" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2774cc3b-de61-4fcb-88aa-d52137894504")) {                    Plotly.newPlot(                        "2774cc3b-de61-4fcb-88aa-d52137894504",                        [{"x":["framework","relational","ubiquitous","components","demonstrate","techniques","component","necessity","statistical","evaluated","predicting","classifiers","selecting","representations","classifier","outperform","competing","discovering","representation","algorithms","attributes","ensembles","granularity","sophisticated","information","influence","capability","snapshots","additionally","classification","traditional","dimension","clusterings","approximation","incomplete","parameters","convergence","subcomponent","alternative","realworld","generalized","exploring","posterior","conditional","approximations","clustering","advantage","applicability","dirichlet","posteriors","estimating","effectiveness","improving","marginalizes","inference","empirically","transferability","discovery","empirical","architectures","innovation","interesting","contribute","accuracies","massively","biological","multitask","accelerate","investigate","algorithmic","performing","underscore","significantly","improvement","synthesizes","predictive","additional","measurements","structured","predictions","discusses","understanding","supervised","contributed","interdependent","concerned","different","performance","extension","implementation","available","constraints","causation","continuity","sufficiency","literature","exploratory","correspond","incorporating","abnormality","modelling","minimizing","definitions","intuition","intervention","application","minimization","definition","incorporates","experimental","congested","attention","variation","locations","challenging","reliability","adaptively","conditions","separately","inevitable","overestimate","detection","appropriate","densities","accurately","exclusively","generating","sufficient","applications","estimation","regression","estimations","underlying","experiments","harmonization","argumentative","brazilian","languages","treebanks","competitive","including","knowledge","annotated","documents","portuguese","linguistic","discourse","structure","evaluating","attracted","processes","euclidean","reproducing","suggested","superiority","confirmed","functions","characterizes","previously","independent","regressions","approximates","respective","fundamental","characterizations","classifications","construction","probability","explicitly","characterization","criterion","distribution","probabilistic","dependency","bidirectional","architecture","propagation","character","introduce","combination","efficiently","automatically","projective","directional","exploiting","marginals","partition","procedure","convolutional","categories","microsoft","optimizing","qualitative","quantitatively","effectively","extensive","instances","embedding","connections","development","opportunity","recognition","concatenate","gradients","generally","improvements","connection","vanishing","respectively","confusion","dimensions","increased","advantages","direction","simulation","practical","consistent","recursive","assumptions","properties","theoretical","uniformly","moderately","elimination","situations","potentials","irregularly","observers","selection","succeeded","coefficients","inpainting","currently","exponential","responses","irregular","statistics","interaction","likelihood","stochastic","objective","continuum","comparison","effective","constrained","synthesis","generalise","surrounding","optimisation","distributions","composition","generalisation","interactions","experimentally"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	emphdirectly
# 	smoothers
# 	conjugacy
# 	intentionally
# 	amortised
# 	multisensor
# 	diffraction
# 	spherically
# 	covariates
# 	disproportionately
# 	discourages
# 	adversarially
# 	representer
# 	minimizers
# 	uncollapsed
# 	transformative
# 	genuinely
# 	sociology
# 	distributedly
# 	robustification
# Some words which never appear in Statistics papers:
# 	subcomponent
# 	realworld
# 	congested
# 	harmonization
# 	argumentative
# 	brazilian
# 	treebanks
# 	portuguese
# 	discourse
# 	observers
# 	realizing
# 	programmable
# 	differentials
# 	activitynet
# 	recognise
# 	bisection
# 	vietnamese
# 	morphosyntactic
# 	minimalist
# 	tentative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0876586284620374e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
