# %% [markdown]
# <a href="https://colab.research.google.com/github/Kondasravanireddy/fake-news-detection/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 14:39:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  84.3MB/s    in 0.8s
#
# 2024-03-26 14:39:17 (84.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11833  1702.06819v4  Recent successes in word embedding and documen...  stat
# 1735    1412.6418v3  In this work, we propose a new method to integ...    cs
# 28226  1705.10120v1  Person recognition methods that use multiple b...    cs
# 4738   1612.05159v2  In this paper, we propose a framework for solv...    cs
# 14293  1703.03859v1  The time to converge to the steady state of a ...  stat
# ...             ...                                                ...   ...
# 6432   1701.08473v2  Point patterns are sets or multi-sets of unord...    cs
# 21558   1011.1026v1  The performance of the Lasso is well understoo...  stat
# 16777  1706.00139v3  Natural language generation (NLG) is a critica...    cs
# 5518    1205.2660v1  We present an objective function for learning ...    cs
# 3520   1710.11052v1  Two of the most popular modelling paradigms in...  stat
#
#                                                    title  year  \
# 11833    SIGNet: Scalable Embeddings for Signed Networks  2017
# 1735   Inducing Semantic Representation from Text by ...  2014
# 28226                      Pose-Aware Person Recognition  2017
# 4738    Separation of Concerns in Reinforcement Learning  2016
# 14293          Markov Chain Lifting and Distributed ADMM  2017
# ...                                                  ...   ...
# 6432   Model-based Classification and Novelty Detecti...  2017
# 21558                 The Lasso under Heteroscedasticity  2010
# 16777  Natural Language Generation for Spoken Dialogu...  2017
# 5518   Alternating Projections for Learning with Expe...  2012
# 3520   A Connection between Feed-Forward Neural Netwo...  2017
#
#                                                 keywords
# 11833  [successes, embedding, embedding, motivated, r...
# 1735   [integrate, unsupervised, induction, semantics...
# 28226  [recognition, significant, improvements, tradi...
# 4738   [framework, different, advantages, specialized...
# 14293  [operation, quadratic, objectives, analogous, ...
# ...                                                  ...
# 6432   [unordered, classification, detection, appropr...
# 21558  [performance, understood, assumptions, homosce...
# 16777  [generation, component, recurrent, architectur...
# 5518   [objective, unlabeled, auxiliary, expectation,...
# 3520   [modelling, paradigms, probabilistic, graphica...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11833    [successes, embedding, embedding, motivated, r...
# 1735     [integrate, unsupervised, induction, semantics...
# 28226    [recognition, significant, improvements, tradi...
# 4738     [framework, different, advantages, specialized...
# 14293    [operation, quadratic, objectives, analogous, ...
#                                ...
# 10343    [unsupervised, estimation, fundamental, applic...
# 37955    [introduce, algorithm, classification, extensi...
# 22260    [blitzkriging, inference, processes, applicabl...
# 38407    [perspective, establish, remarkable, equivalen...
# 35849    [experience, regarding, unorganized, knowledge...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8746 words.
# Out of those 4555 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="87c1ba4b-2c14-4fc1-abaf-3b9c99e928a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87c1ba4b-2c14-4fc1-abaf-3b9c99e928a2")) {                    Plotly.newPlot(                        "87c1ba4b-2c14-4fc1-abaf-3b9c99e928a2",                        [{"x":["particular","embeddings","superiority","demonstrate","prediction","distributed","structural","successes","community","neighborhoods","polarities","representations","detection","objective","representation","different","reinforcing","embedding","principles","carefully","researchers","vocabulary","motivated","reasoning","approaches","structure","traditional","incorporate","components","estimated","syntactic","component","predicting","unsupervised","reconstruction","induction","knowledge","integrate","resources","factorizing","annotated","factorization","linguistic","correspond","semantics","relations","utilizing","improvements","variations","challenges","introduce","benchmarks","scenarios","previously","including","significant","variation","recognition","optimizes","framework","hierarchical","decomposition","transferring","generalizes","experiments","separation","reinforcement","empirical","specialized","advantages","illustrate","quadratic","convergence","parameter","sometimes","analogous","operation","algorithm","objectives","conjecture","iterations","generative","leveraging","beautiful","adversarial","paintings","conditional","synthesize","adaptively","appealing","buildings","childhood","algorithms","smoothing","extraction","synthesis","information","generated","optimization","metalevel","necessarily","selection","sequences","simulation","applicable","simulating","approximations","statistical","selecting","heuristic","intuitive","sequential","appropriate","approximately","theoretical","procedures","heuristics","decisions","estimating","improvement","computations","counterexample","applications","developed","distribution","cooperative","participants","presented","cooperatively","vulnerable","evaluations","interconnected","contribute","detections","therefore","intersection","limitations","infrastructure","occlusions","cooperation","particularly","numerical","tractability","maintaining","tournament","projection","specified","combinatorial","implementation","evaluation","basketball","programming","implement","implementing","databases","dependent","subjective","classifiers","collected","independent","identification","respectively","performance","environments","extremely","outperforms","simulated","proposing","straightforward","generalized","multipliers","efficient","potentially","alternating","generalization","directions","covariates","extension","estimator","guaranteed","interactions","formulated","regression","involving","bandwidth","connection","optimizing","construct","laplacians","geometric","laplacian","represented","riemannian","effective","principled","exploiting","consistency","phenomenon","experimental","comparatively"],"y":[288,74,39,575,253,113,76,6,80,8,1,234,373,173,339,765,2,110,35,31,68,39,58,135,425,324,168,67,104,57,31,104,86,147,107,23,364,56,64,1,85,38,67,30,100,103,42,103,70,122,356,98,89,76,259,294,70,394,14,549,116,67,17,28,620,27,123,128,20,95,70,31,137,138,16,10,41,823,43,13,29,121,49,2,103,6,96,18,24,20,4,1,563,27,113,40,680,176,304,2,13,154,115,80,51,9,29,148,50,60,28,75,76,28,141,29,39,55,68,167,47,5,437,182,196,21,27,179,2,13,50,6,36,13,133,11,43,9,19,7,88,85,9,37,3,37,19,28,152,244,5,110,67,30,59,58,30,118,82,152,93,91,884,72,52,266,63,28,20,70,13,376,44,28,100,35,0,77,29,26,65,31,135,60,12,53,42,72,2,62,9,77,16,239,26,71,65,23,410,5],"type":"bar"},{"x":["particular","embeddings","superiority","demonstrate","prediction","distributed","structur ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4555,), (4555, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8058333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Agent</span> <span style=''>Based</span> <span style=''>Decision</span> <span style=''>Support</span> <span style=''>System</span> <span style=''>to</span> <span style=''>Prevent</span> <span style=''>and</span> <span style=''>Manage</span> <span style=''>Risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Situations</span> <br/><br/><span style=''>The</span> <span style=''>topic</span> <span style=''>of</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>prevention</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>emergency</span> <span style=''>response</span> <span style=''>has</span> <span style=''>become</span> <span style=''>a</span> <span style=''>key</span> <span style=''>social</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>political</span> <span style=''>concern</span> <span style=''>One</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>is</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>Decision</span> <span style=''>Support</span> <span style=''>Systems</span> <span style=''>(DSS)</span> <span style=''>that</span> <span style=''>can</span> <span style=''>help</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>emergency</span> <span style=''>planners</span> <span style=''>and</span> <span style=''>responders</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>emergencies</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>to</span> <span style=''>suggest</span> <span style=''>possible</span> <span style=''>course</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>emergency</span> <span style=''>Our</span> <span style=''>research</span> <span style=''>work</span> <span style=''>comes</span> <span style=''>in</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>DSS</span> <span style=''>that</span> <span style=''>must</span> <span style=''>be</span> <span style=''>generic</span> <span style=''>as</span> <span style=''>much</span> <span style=''>as</span> <span style=''>possible</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>from</span> <span style=''>the</span> <span style=''>case</span> <span style=''>study</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Performance</span> <span style=''>Limits</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Sub</span> <span style=''>Gradient</span> <span style=''>Learning</span> <span style=''>Part</span> <span style=''>I</span> <span style=''>Single</span> <span style=''>Agent</span> <span style=''>Case</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supporting</span> <span style=''>Part</span> <span style=''>II</span> <span style=''>we</span> <span style=''>examine</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>sub</span> <span style=''>gradient</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>under</span> <span style=''>weaker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>than</span> <span style=''>usually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>The</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>are</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfied</span> <span style=''>by</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>cases</span> <span style=''>of</span> <span style=''>interest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>SVM</span> <span style=''>LASSO</span> <span style=''>and</span> <span style=''>Total</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Variation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>denoising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulations</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>do</span> <span style=''>not</span> <span style=''>satisfy</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>used</span> <span style=''>in</span> <span style=''>prior</span> <span style=''>analyses</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conclusions</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>these</span> <span style=''>earlier</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatments</span> <span style=''>are</span> <span style=''>not</span> <span style=''>directly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>The</span> <span style=''>results</span> <span style=''>in</span> <span style=''>this</span> <span style=''>article</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>sub</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.30073349633251845);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.5892857142857142);'>Variational</span> <span style='background-color:rgba(255, 0, 0, 0.3458262350936968);'>Inference</span> <span style=''>for</span> <span style=''>Fully</span> <span style=''>Bayesian</span> <span style=''>Sparse</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(255, 0, 0, 0.4556451612903226);'>Regression</span> <span style=''>Models</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.5892857142857142);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3458262350936968);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>deriving</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>sparse</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.4556451612903226);'>regression</span> <span style=''>(SGPR)</span> <span style=''>models</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.49999999999999994);'>approximations</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>variationally</span> <span style=''>optimal</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style=''>full</span> <span style=''>rank</span> <span style=''>GPR</span> <span style=''>model</span> <span style=''>enriched</span> <span style=''>with</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>noises</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.5892857142857142);'>variational</span> <span style=''>Bayesian</span> <span style=''>SGPR</span> <span style=''>(VBSGPR)</span> <span style=''>models</span> <span style=''>jointly</span> <span style=''>treat</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3793103448275861);'>distributions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>inducing</span> <span style='background-color:rgba(255, 0, 0, 0.35903614457831323);'>variables</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hyperparameters</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.5892857142857142);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>decomposability</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5892857142857142);'>variational</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>that</span> <span style=''>in</span> <span style=''>turn</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploited</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.30073349633251845);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>Such</span> <span style=''>a</span> <span style='background-color:rg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>GANGs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Network</span> <span style=''>Games</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <span style=''>(GAN)</span> <span style=''>have</span> <span style=''>become</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frameworks</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>modeling</span> <span style=''>As</span> <span style=''>GANs</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>train</span> <span style=''>much</span> <span style=''>research</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>this</span> <span style=''>However</span> <span style=''>very</span> <span style=''>little</span> <span style=''>of</span> <span style=''>this</span> <span style=''>research</span> <span style=''>has</span> <span style=''>directly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploited</span> <span style=''>game</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Network</span> <span style=''>Games</span> <span style=''>(GANGs)</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>model</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>zero</span> <span style=''>sum</span> <span style=''>game</span> <span style=''>between</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generator</span> <span style=''>(G)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>(C)</span> <span style=''>that</span> <span style=''>use</span> <span style=''>mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>The</span> <span style=''>size</span> <span style=''>of</span> <span style=''>these</span> <span style=''>games</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precludes</span> <span style=''>exact</span> <span style=''>solution</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style=''>we</span> <span style=''>define</span> <span style=''>resource</span> <span style=''>bounded</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>(RBBRs)</span> <span style=''>and</span> <span style=''>a</span> <span style=''>resource</span> <span style=''>bounded</span> <span style=''>Nash</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Equilibrium</span> <span style=''>(RB</span> <span style=''>NE)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>pair</span> <span style=''>of</span> <span style=''>mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>such</span> <span style=''>that</span> <span style=''>neither</span> <span style=''>G</span> <span style=''>or</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10693848354792561)
# 	architecture (0.09084406294706723)
# 	experimental (0.14663805436337626)
# 	segmentation (0.07188841201716738)
# 	knowledge (0.1301859799713877)
# 	information (0.24320457796852646)
# 	detection (0.13340486409155938)
# 	different (0.27360515021459225)
# 	convolutional (0.1430615164520744)
# 	recognition (0.14091559370529327)
#
# Some Statistics words are:
# 	stochastic (0.13273453093812376)
# 	statistical (0.14321357285429143)
# 	variables (0.1407185628742515)
# 	algorithm (0.39271457085828343)
# 	theoretical (0.14920159680638723)
# 	estimation (0.1751497005988024)
# 	distribution (0.18163672654690619)
# 	dimensional (0.18063872255489022)
# 	inference (0.19710578842315368)
# 	regression (0.18013972055888225)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="78eff91e-b2ce-46ee-8080-bb8ec9c52ff5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78eff91e-b2ce-46ee-8080-bb8ec9c52ff5")) {                    Plotly.newPlot(                        "78eff91e-b2ce-46ee-8080-bb8ec9c52ff5",                        [{"x":["particular","embeddings","superiority","demonstrate","prediction","distributed","structural","successes","community","neighborhoods","polarities","representations","detection","objective","representation","different","reinforcing","embedding","principles","carefully","researchers","vocabulary","motivated","reasoning","approaches","structure","traditional","incorporate","components","estimated","syntactic","component","predicting","unsupervised","reconstruction","induction","knowledge","integrate","resources","factorizing","annotated","factorization","linguistic","correspond","semantics","relations","utilizing","improvements","variations","challenges","introduce","benchmarks","scenarios","previously","including","significant","variation","recognition","optimizes","framework","hierarchical","decomposition","transferring","generalizes","experiments","separation","reinforcement","empirical","specialized","advantages","illustrate","quadratic","convergence","parameter","sometimes","analogous","operation","algorithm","objectives","conjecture","iterations","generative","leveraging","beautiful","adversarial","paintings","conditional","synthesize","adaptively","appealing","buildings","childhood","algorithms","smoothing","extraction","synthesis","information","generated","optimization","metalevel","necessarily","selection","sequences","simulation","applicable","simulating","approximations","statistical","selecting","heuristic","intuitive","sequential","appropriate","approximately","theoretical","procedures","heuristics","decisions","estimating","improvement","computations","counterexample","applications","developed","distribution","cooperative","participants","presented","cooperatively","vulnerable","evaluations","interconnected","contribute","detections","therefore","intersection","limitations","infrastructure","occlusions","cooperation","particularly","numerical","tractability","maintaining","tournament","projection","specified","combinatorial","implementation","evaluation","basketball","programming","implement","implementing","databases","dependent","subjective","classifiers","collected","independent","identification","respectively","performance","environments","extremely","outperforms","simulated","proposing","straightforward","generalized","multipliers","efficient","potentially","alternating","generalization","directions","covariates","extension","estimator","guaranteed","interactions","formulated","regression","involving","bandwidth","connection","optimizing","construct","laplacians","geometric","laplacian","represented","riemannian","effective","principled","exploiting","consistency","phenomenon","experimental","comparatively","comprehensive","technology","available","furthermore","following","significance","retrieval","remarkable","according","systematic","investigation","geological","resolution","relevance","conclusions","similarity","complexity","evaluating","acceptable","combining","constructed","sentences","situations","highlighted","respective","documents","convenient","displayed","scalability","procedure","supported","application","understand","investigated","orientation","principle","analytical","intelligence","formation","circulating","widespread","automated","continuously","treatment","behaviour","parameters","accomplishes","important","effectively","scientists","ontologies","automatic","represent","transformational","categorize","considers","environment","sear ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	covariates
# 	harnessed
# 	algebraically
# 	deflation
# 	unavoidably
# 	stationarities
# 	interfacing
# 	compensating
# 	heteroscedastic
# 	determinantal
# 	oscillates
# 	diagnostics
# 	spectrometry
# 	prioritization
# 	similitude
# 	constants
# 	assimilated
# 	assimilating
# 	depression
# 	schizophrenia
# Some words which never appear in Statistics papers:
# 	syntactic
# 	paintings
# 	metalevel
# 	cooperatively
# 	interconnected
# 	occlusions
# 	circulating
# 	accomplishes
# 	ontologies
# 	transformational
# 	folksonomies
# 	certification
# 	assistants
# 	determinism
# 	trustworthiness
# 	replicating
# 	isabellehol
# 	incidental
# 	surpasses
# 	switchboard

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075503613716746e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
